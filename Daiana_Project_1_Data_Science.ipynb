# %% [markdown]
# <a href="https://colab.research.google.com/github/daiana-o/DS-Milestone-1-Project/blob/main/Daiana_Project_1_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Milestone 1

# %% [markdown]
# ### Step 1: choose a dataset

# %% [markdown]
# Choose any interesting dataset that meets these criteria:
# * in CSV format (or you have put it in this format)
# * each row represents one observation
# * at least four columns of data
# * at least one column of qualitative (categorical) data with duplicate values
#
# * at least two columns of quantitative data (integer or real number data that are measurements, not categorical data where the categories are numbers like zip codes)
# * at least 300 rows of data
# * The above criteria are a minimum, and you will have more choices for the project analysis if your data has more than 4 columns, more than 1 column of repeated categorical data, and more than 2 columns of quantitative data.  For Milestone 2, you will be trying to predict the category/value in one of the columns, using data from the other columns.

# %% [markdown]
# ####Dataset found here:
# https://www.kaggle.com/datasets/rhythmghai/netflix-user-watching-behavior-dataset/data
# ####CSV file name here:
# netflix_user_behavior_dataset.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_user_behavior_dataset.csv")
df
# Out:
#        user_id  age  gender country  account_age_months subscription_type  \
# 0      U100000   56    Male   India                  17          Standard
# 1      U100001   46  Female     USA                  20          Standard
# 2      U100002   32   Other     USA                  25             Basic
# 3      U100003   60    Male  Canada                  37          Standard
# 4      U100004   25    Male  Brazil                  23           Premium
# ...        ...  ...     ...     ...                 ...               ...
# 49995  U149995   60  Female   Japan                  30          Standard
# 49996  U149996   46   Other  Brazil                  39          Standard
# 49997  U149997   19    Male      UK                  53             Basic
# 49998  U149998   43  Female      UK                  19          Standard
# 49999  U149999   28   Other   India                  35             Basic
#
#        monthly_fee payment_method primary_device  devices_used favorite_genre  \
# ...

# %% [markdown]
# ####Step 2: create a GitHub account

# %% [markdown]
# * create a GitHub account
# * create a new repository for your project
# * upload your data file to this repository. If your data file is too large to upload to GitHub, you do not have to upload it. Instead, make sure there is a clear link to the original data source on your webpage.
#
#
# Github: All code for your project must be uploaded to  GitHub, a free, widely-used website for storing code, with a focus on tracking changes and encouraging collaboration. You can use a free public repository (directory), or, as a student,  apply for free private repositories.
#
#
# * GitHub Basic Tutorial
# * GitHub tutorial (video)

# %% [markdown]
# ##WEBSITE LINK BELOW:

# %% [markdown]
# ####Step 3: create a webpage

# %% [markdown]
# * Create a webpage for your project
#
# Website: You will submit your project as a website that describes your data, the results of your analyses, and conclusions drawn from them.   A website makes it easy to present both graphics and text, and can easily be shown to other people (such as prospective employers).
# Easy, free ways to create a webpage (though you may use whatever you like):
#
# * sites.google.com. (recommended)
# * www.wix.com

# %% [markdown]
# ####Step 4: Data description and assessment

# %% [markdown]
# On your webpage:
#
# a) Write a paragraph introducing and describing your dataset to the reader.  Consider including the following information in the description:
#
# * why you are interested in this data
# * where you found the dataset (including link)
# * who (person, government, organization, company, etc.) created the dataset
# * what kind of information is contained in the dataset
#
# b) Assess the data by answering the questions in Lab 3:
# * What is the structure or shape of the data?
# * What is the granularity of the data?
# * What is the scope and completeness of the data?
# * What is the temporality of the data, or how does the data relate to time?
# * What is the faithfulness of the data, or how well does the data capture reality?

# %% [markdown]
# ####Step 5: cleaning your data

# %% [markdown]
# a) If necessary, clean your data (ex. handle missing and erroneous data, remove extra characters in quantitative data columns, etc).  As you explore your data in later steps, you may realize additional cleaning needs to be done.  If so, just come back and update this step.
#
# b) Describe what steps (if any) you took to clean your data on your webpage.  In particular, even if you did not need to clean your data, you must still state this on your webpage for full credit.

# %%
df.isna().sum()
# Out:
# user_id                      0
# age                          0
# gender                       0
# country                      0
# account_age_months           0
# subscription_type            0
# monthly_fee                  0
# payment_method               0
# primary_device               0
# devices_used                 0
# favorite_genre               0
# avg_watch_time_minutes       0
# watch_sessions_per_week      0
# binge_watch_sessions         0
# completion_rate              0
# rating_given                 0
# content_interactions         0
# recommendation_click_rate    0
# days_since_last_login        0
# churned                      0
# dtype: int64

# %%
df.describe()
# Out:
#                 age  account_age_months   monthly_fee  devices_used  \
# count  50000.000000        50000.000000  50000.000000  50000.000000
# mean      40.979240           29.874000     12.323340      1.999140
# std       13.528733           17.051104      3.309109      0.818238
# min       18.000000            1.000000      7.990000      1.000000
# 25%       29.000000           15.000000      7.990000      1.000000
# 50%       41.000000           30.000000     12.990000      2.000000
# 75%       53.000000           45.000000     15.990000      3.000000
# max       64.000000           59.000000     15.990000      3.000000
#
#        avg_watch_time_minutes  watch_sessions_per_week  binge_watch_sessions  \
# count            50000.000000             50000.000000          50000.000000
# mean               154.946520                 9.986920              7.002520
# std                 83.727292                 5.480616              4.335819
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   user_id                    50000 non-null  object
#  1   age                        50000 non-null  int64
#  2   gender                     50000 non-null  object
#  3   country                    50000 non-null  object
#  4   account_age_months         50000 non-null  int64
#  5   subscription_type          50000 non-null  object
#  6   monthly_fee                50000 non-null  float64
#  7   payment_method             50000 non-null  object
#  8   primary_device             50000 non-null  object
#  9   devices_used               50000 non-null  int64
#  10  favorite_genre             50000 non-null  object
#  11  avg_watch_time_minutes     50000 non-null  int64
#  12  watch_sessions_per_week    50000 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["user_id"].value_counts()
# Out:
# user_id
# U149983    1
# U149982    1
# U149981    1
# U149980    1
# U149979    1
#           ..
# U100004    1
# U100003    1
# U100002    1
# U100001    1
# U100000    1
# Name: count, Length: 50000, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    16759
# Male      16737
# Other     16504
# Name: count, dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# Brazil       5116
# USA          5087
# India        5028
# Spain        5027
# Germany      5024
# Australia    5004
# Canada       4959
# UK           4929
# France       4919
# Japan        4907
# Name: count, dtype: int64

# %%
df["subscription_type"].value_counts()
# Out:
# subscription_type
# Standard    19931
# Premium     15196
# Basic       14873
# Name: count, dtype: int64

# %%
df["payment_method"].value_counts()
# Out:
# payment_method
# PayPal         12539
# Credit Card    12502
# UPI            12496
# Debit Card     12463
# Name: count, dtype: int64

# %%
df["primary_device"].value_counts()
# Out:
# primary_device
# Mobile      12585
# Smart TV    12562
# Laptop      12509
# Tablet      12344
# Name: count, dtype: int64

# %%
df["favorite_genre"].value_counts()
# Out:
# favorite_genre
# Documentary    6352
# Romance        6282
# Comedy         6259
# Thriller       6257
# Action         6235
# Horror         6223
# Drama          6203
# Sci-Fi         6189
# Name: count, dtype: int64

# %%
df["churned"].value_counts()
# Out:
# churned
# No     40036
# Yes     9964
# Name: count, dtype: int64

# %% [markdown]
# ####Step 6: single variable distribution plots

# %% [markdown]
# Choose 4 columns and do the following for each of these columns:
# 1. Plot the distribution of data in that column using an appropriate graph type.
# 2. Add a title and axes labels to the plot.
# 3. Add the plot to your webpage and write several sentences telling the reader what they should notice about the plot (ex. shape of distribution, outliers, skew, anything surprising, etc)
#
# Add your code for this step to your GitHub account.

# %%
df["country"].value_counts().plot(kind="bar")
plt.title("Country of Users")
plt.xlabel("Country")
plt.ylabel("Number of Users")
plt.show()

# %%
df["watch_sessions_per_week"].hist(bins=20)
plt.title("Weekly Watch Sessions Per User")
plt.xlabel("Watch Session Per Week")
plt.ylabel("Number of Users")
plt.show()

# %%
df["avg_watch_time_minutes"].hist(bins=20)
plt.title("Average Watch Time Per User")
plt.xlabel("Average Watch Time (Minutes)")
plt.ylabel("Number of Users")
plt.show()

# %%
df["favorite_genre"].value_counts().plot(kind="bar")
plt.title("Favorite Genre of Users")
plt.xlabel("Genre")
plt.ylabel("Number of Users")
plt.show()

# %% [markdown]
# ####Step 7: multiple variable plots

# %% [markdown]
# Create 2 plots by doing the following for each:
#
#     a) Choose two or more columns/variables, and create a plot visualizing their relationship.
#
#     b) Add a title and axes labels to the plot.
#
#     c) Add the plot to your webpage and write several sentences telling the reader what they should notice or conclude from this plot.
#
#
# Add the code for this step to your GitHub account.

# %%
sns.scatterplot(x="avg_watch_time_minutes", y="watch_sessions_per_week", hue="gender", data=df)
plt.title("Average Watch Time vs. Weekly Watch Sessions by Different Genders")
plt.xlabel("Average Watch Time (Minutes)")
plt.ylabel("Weekly Watch Sessions")
plt.show()

# %%
sns.barplot(x="country", y="days_since_last_login", hue="churned", data=df)
plt.title("Days Since Last Login by Country in Relation to Churned Status")
plt.xlabel("Country")
plt.ylabel("Days Since Last Login")
plt.show()
